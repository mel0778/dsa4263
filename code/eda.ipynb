# %% [markdown]
# **Masterfile**
# - The insiders.csv file is the master file of true positives incidents (malicious user activity).
# - It contains the dataset reference, scenario type (1-5 as referenced in scenarios.txt), incident observation filename, userid, start and end timestamps of incident

# %%
import pandas as pd

masterfile_data = pd.read_csv("../data/answers/insiders.csv")
masterfile_data
# Out:
#      dataset  scenario     details     user                start  \
# 0        2.0         1      r2.csv  ONS0995     3/6/2010 1:41:56
# 1        3.1         1  r3.1-1.csv  CSF0929  07/01/2010 01:24:58
# 2        3.1         2  r3.1-2.csv  CCH0959  08/02/2010 10:34:31
# 3        3.2         1  r3.2-1.csv  RCW0822  09/29/2010 21:10:27
# 4        3.2         2  r3.2-2.csv  JCE0258  07/12/2010 08:16:02
# ..       ...       ...         ...      ...                  ...
# 186      6.2         1  r6.2-1.csv  ACM2278   8/18/2010 21:47:42
# 187      6.2         2  r6.2-2.csv  CMP2946  02/07/2011 12:28:06
# 188      6.2         3  r6.2-3.csv  PLJ1771   8/12/2010 08:09:00
# 189      6.2         4  r6.2-4.csv  CDE1846    /21/2011 11:43:39
# 190      6.2         5  r6.2-5.csv  MBG3183  10/12/2010 13:21:59
#
#                      end
# 0      3/20/2010 8:10:12
# 1    07/16/2010 06:52:00
# 2    09/30/2010 15:04:03
# 3    10/15/2010 06:34:52
# 4    09/03/2010 16:16:29
# ..                   ...
# ...

# %%
# Breakdown of scenario types --> Might have to do resampling
pd.Series(masterfile_data['scenario']).value_counts()
# Out:
# scenario
# 1    66
# 2    66
# 4    33
# 3    24
# 5     2
# Name: count, dtype: int64
